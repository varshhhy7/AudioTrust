# %%
# !pip install -q torch librosa faiss-cpu transformers numpy pandas scikit-learn scipy torchaudio soundfile duckdb
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 113.0 MB/s eta 0:00:0000:0100:01

# %%
import os
import sys
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim 
from torch.utils.data import DataLoader, Dataset 
import numpy as np 
import pandas as pd
import librosa
import soundfile as sf
import faiss
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path
import logging 
from datetime import datetime
import pickle
import json 
import hashlib 
import warnings 
warnings.filterwarnings("ignore")

modules = [
    "torch", "librosa", "soundfile", "faiss", "sklearn",
    "matplotlib", "seaborn", "pandas", "numpy"
]

for m in modules:
    try:
        __import__(m)
        print(f" {m} imported")
    except Exception as e:
        print(f" {m} failed: {e}")
# Out:
#  torch imported
#  librosa imported
#  soundfile imported
#  faiss imported
#  sklearn imported
#  matplotlib imported
#  seaborn imported
#  pandas imported
#  numpy imported
